# %% [markdown]
# # EJERCICIOS TEÓRICOS
# ## Ejercicio 2:
#
# ![image.png](attachment:image.png)

# %%
import math

# Función f(x) = sin(pi * x)
def f(x):
    return math.sin(math.pi * x)

# Método de bisección
def biseccion(a, b, tol=1e-6, max_iter=100):
    if f(a) * f(b) > 0:
        raise ValueError("La función no cambia de signo en el intervalo.")

    for _ in range(max_iter):
        c = (a + b) / 2
        if abs(f(c)) < tol or (b - a) / 2 < tol:
            return c
        if f(a) * f(c) < 0:
            b = c
        else:
            a = c
    return c

# %% [markdown]
# ### Caso a

# %%
a1 = -0.9
b1 = 2.5  

raiz_a = biseccion(a1, b1)
print(f"Literal a → Raíz ≈ {raiz_a:.6f} → Converge a x = {round(raiz_a)}")
# Out:
# Literal a → Raíz ≈ 0.000000 → Converge a x = 0

# %% [markdown]
# ### Caso b

# %%
a2 = -0.2
b2 = 2.5 

raiz_b = biseccion(a2, b2)
print(f"Literal b → Raíz ≈ {raiz_b:.6f} → Converge a x = {round(raiz_b)}")
# Out:
# Literal b → Raíz ≈ 2.000000 → Converge a x = 2

# %% [markdown]
# ### Caso c

# %%
a3 = -0.5
b3 = 2.5 

raiz_c = biseccion(a3, b3)
print(f"Literal c → Raíz ≈ {raiz_c:.6f} → Converge a x = {round(raiz_c)}")
# Out:
# Literal c → Raíz ≈ 1.000000 → Converge a x = 1
